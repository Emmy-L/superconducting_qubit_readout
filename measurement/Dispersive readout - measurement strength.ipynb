# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# %%
Nc = 16
Nq = 3

epsilon = 0e6 * 2 * np.pi # note how the power has units of frequency here - a rate of photon addition
w_c  = 2 * np.pi * 5.0e9 # resonator frequency
w_q  = 2 * np.pi * 4e9 # qubit frequency
w_1 = 2 * np.pi * 5.0e9  # drive
phi_1 = 0*np.pi/2 # phase
kappa = 1e6 * 2 * np.pi           # cavity dissipation rate
alpha = 200e6 * 2 * np.pi
g = 100e6 * 2 * np.pi
T = 0
gamma = 0e6 * 2 * np.pi

c  = tensor(destroy(Nc), qeye(Nq))

q = tensor(qeye(Nc), destroy(Nq))

tlist = np.linspace(0, 2e-6, 20000)

H0 = w_c * c.dag() * c + w_q * q.dag() * q + alpha/2*q.dag()*q.dag()*q*q + g*(c.dag() + c)*(q.dag() + q)

H1_I = c # quadratures of the drive

H1_Q = c.dag()

cav_drive = epsilon*np.exp(1j*w_1*tlist + 1j*phi_1)

H = [[H0, tlist*0 + 1],[H1_I,cav_drive],[H1_Q,np.conj(cav_drive)]]

H0.eigenenergies()/(2*np.pi)

c_op_list = []

rate = gamma * (1 + T)
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * q)

rate = gamma * T
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * q.dag())

rate = kappa
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * c)

psi_0 = tensor(coherent(Nc, 2), (fock(Nq, 0) + fock(Nq, 1))/np.sqrt(2))

# %%
result = mesolve(H, psi_0, tlist, c_ops = c_op_list)

# %%
# i = 0

# fig, axes = plt.subplots(1, 2, figsize=(10, 5))
# axes[0].cla()
# plot_fock_distribution(result.states[i], fig=fig, ax=axes[0])
# plot_wigner(result.states[i], fig=fig, ax=axes[1])
# plt.show()

i = -1

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].cla()
plot_fock_distribution(result.states[i].ptrace(0), fig=fig, ax=axes[0])
plot_wigner(result.states[i].ptrace(0), fig=fig, ax=axes[1])
plt.show()

# %%
psi_qb = result.states[i].ptrace(1)

# %%
(psi_qb*psi_qb).tr()
# Out:
# 0.5759962144031402

# %%
H0.eigenstates()[0]/(2*np.pi)
# Out:
# array([-1.11179372e+06,  3.98791920e+09,  5.00768363e+09,  8.17533619e+09,
#         9.00159126e+09,  1.00165011e+10,  1.31537696e+10,  1.40143201e+10,
#         1.50253377e+10,  1.81330171e+10,  1.90262186e+10,  2.00341903e+10,
#         2.31129893e+10,  2.40373792e+10,  2.50430562e+10,  2.80936122e+10,
#         2.90478787e+10,  3.00519325e+10,  3.30748237e+10,  3.40577816e+10,
#         3.50608168e+10,  3.80565712e+10,  3.90671431e+10,  4.00697065e+10,
#         4.30388097e+10,  4.40760105e+10,  4.50785993e+10,  4.80215000e+10,
#         4.90844252e+10,  5.00874929e+10,  5.30046083e+10,  5.40924234e+10,
#         5.50963853e+10,  5.79881045e+10,  5.91000368e+10,  6.01052743e+10,
#         6.29719624e+10,  6.41072938e+10,  6.51141582e+10,  6.79561588e+10,
#         6.91142283e+10,  7.01230878e+10,  7.29409011e+10,  7.41238010e+10,
#         7.51464862e+10,  7.79497580e+10,  7.92973463e+10,  8.32326840e+10])

# %%
(fock(Nq, 0) + fock(Nq, 1))/np.sqrt(2)
# Out:
# Quantum object: dims=[[3], [1]], shape=(3, 1), type='ket', dtype=Dense
# Qobj data =
# [[0.70710678]
#  [0.70710678]
#  [0.        ]]

# %%
result.states[i].ptrace(1)
# Out:
# Quantum object: dims=[[3], [3]], shape=(3, 3), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[ 7.09831369e-01+9.49111575e-17j  2.50619677e-03+6.97029217e-03j
#   -1.11187419e-03+1.60161743e-03j]
#  [ 2.50619677e-03-6.97029217e-03j  2.67382022e-01-1.24825031e-17j
#   -6.82671461e-04+1.58102195e-03j]
#  [-1.11187419e-03-1.60161743e-03j -6.82671461e-04-1.58102195e-03j
#    2.27866083e-02-2.08652429e-17j]]

# %%
purity = tlist*0

for i in range(0, len(tlist)):
    
    psi_qb = result.states[i].ptrace(1)
    purity[i] = np.abs((psi_qb*psi_qb).tr())
    
plt.plot(tlist, purity)
plt.ylabel('Purity')
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# ## Purity of single oscillator state under decay
#
# The un-approximated dynamics of qubit-resonator dynamics may be complicated. If we only want to consider information flow, it may be helpful to consider just a single oscillator under decay.

# %%
N = 16

epsilon = 0e6 * 2 * np.pi # note how the power has units of frequency here - a rate of photon addition
w_c  = 2 * np.pi * 5.0e9 # resonator frequency
w_1 = 2 * np.pi * 5.0e9  # drive
kappa = 10e6 * 2 * np.pi           # cavity dissipation rate
T = 0.9

c  = destroy(N)

tlist = np.linspace(0, 1e-7, 1000)

H0 = w_c * c.dag() * c

H1_I = c # quadratures of the drive

H1_Q = c.dag()

cav_drive = epsilon*np.exp(1j*w_1*tlist + 1j*phi_1)

H = [[H0, tlist*0 + 1],[H1_I,cav_drive],[H1_Q,np.conj(cav_drive)]]

H0.eigenenergies()/(2*np.pi)

c_op_list = []

rate = kappa * (1 + T)
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * c)

rate = kappa * T
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * c.dag())


psi_0 = coherent(N, 0)

# %%
result = mesolve(H, psi_0, tlist, c_ops = c_op_list)

# %%
i = 500

psi = result.states[i]

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].cla()
plot_fock_distribution(result.states[i], fig=fig, ax=axes[0])
plot_wigner(result.states[i], fig=fig, ax=axes[1])
plt.show()

(psi*psi).tr()
# Out:
# 0.3673151534914197

# %% [markdown]
# # Purity of qubit under decay
#
# Here we look at the other subsystem - the qubit. We start with a X eigenstate (not a stationary state).

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

Nq = 10

w_q  = 2 * np.pi * 4e9 # qubit frequency

alpha = 200e6 * 2 * np.pi
g = 100e6 * 2 * np.pi
T = 0.1
gamma_1 = 10e6 * 2 * np.pi
gamma_phi = 0e6 * 2 * np.pi

q = destroy(Nq)

tlist = np.linspace(0, 1e-7, 1000)

H0 = w_q * q.dag() * q + alpha/2*q.dag()*q.dag()*q*q

H = H0

H0.eigenenergies()/(2*np.pi)

c_op_list = []

rate = gamma_1 * (1 + T)
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * q)

rate = gamma_1 * T
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * q.dag())
    
rate = gamma_phi
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * (q*q.dag()))

psi_0 = (fock(Nq, 0) + fock(Nq, 1))/np.sqrt(2)

# %%
result = mesolve(H, psi_0, tlist, c_ops = c_op_list)

# %%
i = 100

rho = result.states[i]

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].cla()
plot_fock_distribution(result.states[i], fig=fig, ax=axes[0])
plot_wigner(result.states[i], fig=fig, ax=axes[1])
plt.show()

purity = tlist*0
entropy = tlist*0

for i in range(0, len(tlist)):
    
    rho = result.states[i]
    purity[i] = np.abs((rho*rho).tr())
#     entropy[i] = -(rho*rho.logm()).tr()

plt.plot(tlist, purity)
plt.ylabel('Purity')
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# ## Undriven qubit-resonator system - degree of entanglement
#
# Here we are interested to see how the degree of entanglement evolves under a dispersive interaction with no loss. Note here that it is critical to use a diagonalized basis - using chi instead of g, no linear coupling - otherwise the calculation of purity will not make sense, since the bare cavity operators are not the same as the dressed ones, and the partial trace will not be as expected.

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

Nc = 16
Nq = 3

w_c  = 2 * np.pi * 5.0e9 # resonator frequency
w_q  = 2 * np.pi * 4e9 # qubit frequency
kappa = 0e6 * 2 * np.pi           # cavity dissipation rate
alpha = 200e6 * 2 * np.pi
chi = 10e6 * 2 * np.pi
T = 0
gamma = 0e6 * 2 * np.pi
K = 0*chi**2/alpha

c  = tensor(destroy(Nc), qeye(Nq))

q = tensor(qeye(Nc), destroy(Nq))

tlist = np.linspace(0, 2e-7, 2000)

# H0 = w_c * c.dag() * c + w_q * q.dag() * q + alpha/2*q.dag()*q.dag()*q*q + g*(c.dag() + c)*(q.dag() + q)
H0 = w_c * c.dag() * c + w_q * q.dag()*q + alpha/2*q.dag()*q.dag()*q*q + chi*(c.dag()*c*q.dag()*q) + K/2*(c.dag()*c.dag()*c*c)

H = H0

c_op_list = []

rate = gamma * (1 + T)
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * q)

rate = gamma * T
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * q.dag())

rate = kappa
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * c)

psi_0 = tensor(coherent(Nc, 2), (fock(Nq, 0) + fock(Nq, 1) + fock(Nq, 2))/np.sqrt(3))
# psi_0 = tensor(coherent(Nc, 2), (fock(Nq, 0) + fock(Nq, 1))/np.sqrt(2))
# psi_0 = tensor(coherent(Nc, 2), fock(Nq, 1))

rho_0 = psi_0*psi_0.dag()

# %%
result = mesolve(H, rho_0, tlist, c_ops = c_op_list)

# %%
def purity(rho):
    return (rho*rho).tr()

def normalize(psi):
    return psi/np.sqrt(psi.dag()*psi)

def entropy_bits(rho):
    
    return np.log2(np.exp(-(rho*rho.logm()).tr()))


purity_q = tlist*0
purity_c = tlist*0
entanglement = tlist*0
entanglement_entropy = tlist*0

rho_qs = []
rho_cs = []

for i in range(0, len(tlist)):
    
    rho = result.states[i]
    rho_q = rho.ptrace(1)
    rho_c = rho.ptrace(0)
    purity_q[i] = np.abs((rho_q*rho_q).tr())
    purity_c[i] = np.abs((rho_c*rho_c).tr())
    entanglement[i] = 1 - (purity(rho_q)+purity(rho_c) - purity(rho))

    rho_qs.append(rho_q)
    rho_cs.append(rho_c)
    entanglement_entropy[i] = (entropy_bits(rho_q) + entropy_bits(rho_c) - entropy_bits(rho))/2

plt.plot(tlist, purity_c)
plt.plot(tlist, purity_q)
plt.plot(tlist, entanglement)
plt.plot(tlist, entanglement_entropy)
plt.ylabel('Entanglement')
plt.xlabel('Time')
# Out:
# C:\Users\boris\AppData\Local\Temp\ipykernel_56508\3281378840.py:31: ComplexWarning: Casting complex values to real discards the imaginary part
#   entanglement_entropy[i] = (entropy_bits(rho_q) + entropy_bits(rho_c) - entropy_bits(rho))/2
# Text(0.5, 0, 'Time')

# %%
i = 800

fig, axes = plt.subplots(1, 2, figsize=(6, 3))
axes[0].cla()
plot_fock_distribution(result.states[i].ptrace(0), fig=fig, ax=axes[0])
plot_wigner(result.states[i].ptrace(0), fig=fig, ax=axes[1])
plt.show()

# %%
N = 20
temp = 0
disp = displace(N,1)

state = disp*thermal_dm(N,temp)*disp.dag()
state1 = coherent(N,1)*coherent(N,1).dag()
state2 = coherent(N,4)*coherent(N,4).dag()

fig, axes = plt.subplots(1, 2, figsize=(6, 3))
axes[0].cla()
plot_fock_distribution(state, fig=fig, ax=axes[0])
plot_wigner(state, fig=fig, ax=axes[1])
plt.show()

print(entropy_bits(state))
# Out:
# -1.6017132519074588e-16

# %%
(state2.dag()*state1).tr()
# Out:
# (0.00012340980399757893+0j)
